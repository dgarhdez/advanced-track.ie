# %%
import duckdb

con = duckdb.connect("IE_AIRPLANES.duckdb")

print(con.execute("SELECT * FROM AIRPLANES").fetchall())
# Out:
# [('IE00216', 'AIRBUS A320(320) Express', 18.0, None, 162.0, 8, datetime.date(2000, 1, 4), 291, datetime.date(2024, 5, 3), datetime.date(2024, 3, 8), 442, 805, 612677), ('IE02067', 'BOEING B737 (800) V3', 16.0, 42.0, 108.0, 8, datetime.date(2000, 1, 29), 291, datetime.date(2024, 3, 6), datetime.date(2024, 3, 9), 790, 750, 198244), ('IE02258', 'AIRBUS A330-200(332)', 19.0, None, 269.0, 12, datetime.date(2000, 2, 4), 386, datetime.date(2024, 4, 5), datetime.date(2024, 3, 15), 756, 826, 598002), ('IE02343', 'AIRBUS A330-200(332)', 19.0, None, 269.0, 12, datetime.date(2000, 2, 20), 386, datetime.date(2024, 4, 17), datetime.date(2024, 5, 18), 25, 1118, 415083), ('IE02478', 'AIRBUS A320(320) Express', 18.0, None, 162.0, 8, datetime.date(2000, 3, 24), 291, datetime.date(2024, 3, 1), datetime.date(2024, 4, 3), 278, 286, 954376), ('IE04315', 'MCDONNEL DOUGLAS DC-10-30', 22.0, None, 262.0, 12, datetime.date(2000, 4, 15), 386, datetime.date(2024, 4, 5), datetime.date(2024, 3, 31), 117, 2891, 746
# ...
